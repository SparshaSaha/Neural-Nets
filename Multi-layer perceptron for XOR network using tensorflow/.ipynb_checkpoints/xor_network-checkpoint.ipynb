# %%
import tensorflow as tf
import numpy as np

#define the network
nodes_input=2
nodes_hidden_1=3
nodes_output=2

batch_size=1;

x=tf.placeholder('float',[None,2])
y=tf.placeholder('float')

#Define weights for neural network
hidden_l1={'weights':tf.Variable(tf.random_normal([nodes_input,nodes_hidden_1])),'biases':tf.Variable(tf.random_normal([nodes_hidden_1]))}
    
output_layer={'weights':tf.Variable(tf.random_normal([nodes_hidden_1,nodes_output])),'biases':tf.Variable(tf.random_normal([nodes_output]))}

# %%
def get_data(xh):     #function to read data from file
    datafile=open(xh,"r")
    datalist=[]
    for line in datafile:
        z=line.split(",")
        xg=[float(i) for i in z]
        datalist.append(xg)
    f=np.matrix(datalist)
    return datalist

# %%
def xor_nn(data):
    
    #feed forward throught the network
    l1=tf.add(tf.matmul(data,hidden_l1['weights']),hidden_l1['biases'])
    l1=tf.nn.relu(l1)
    
    output=tf.add(tf.matmul(l1,output_layer['weights']),output_layer['biases'])
    return (output)

# %%
def train_neural_network(train_x,train_y):
    prediction=xor_nn(x)
    cost=tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=prediction,labels=y))

    optimizer=tf.train.GradientDescentOptimizer(0.3).minimize(cost)

    hm_epochs=100

    with tf.Session() as sess:
        sess.run(tf.initialize_all_variables())
        saver=tf.train.Saver();

        for epoch in range(hm_epochs):
            epoch_loss=0
            for t in range(4):
                _,c=sess.run([optimizer,cost],feed_dict={x:[train_x[t]],y:[train_y[t]]})
                epoch_loss+=c
                
                correct=tf.equal(tf.argmax(prediction,1),tf.argmax(y,1))
                accuracy=tf.reduce_mean(tf.cast(correct,'float'))
            print('Epoch ',epoch,'conpleted ',hm_epochs,'loss: ',epoch_loss)
        
        save_path = saver.save(sess, "./mymodel")
        
        m=sess.run(prediction,feed_dict={x:train_x})
        m=m.tolist()
        fin_list=[]
        for q in m:
            z=[]
            if(q[0]>q[1]):
                z.append(1)
                z.append(0)
            else:
                z.append(0)
                z.append(1)
            fin_list.append(z)
        print(fin_list)

# %%
ox=get_data("x_data.txt")
oy=get_data("y_data.txt")

train_neural_network(ox,oy)
# Out:
# ('Epoch ', 0, 'conpleted ', 100, 'loss: ', 7.615032404661179)
# ('Epoch ', 1, 'conpleted ', 100, 'loss: ', 3.8643831312656403)
# ('Epoch ', 2, 'conpleted ', 100, 'loss: ', 3.285625785589218)
# ('Epoch ', 3, 'conpleted ', 100, 'loss: ', 3.0644200444221497)
# ('Epoch ', 4, 'conpleted ', 100, 'loss: ', 2.9023929238319397)
# ('Epoch ', 5, 'conpleted ', 100, 'loss: ', 2.7631758749485016)
# ('Epoch ', 6, 'conpleted ', 100, 'loss: ', 2.6610612869262695)
# ('Epoch ', 7, 'conpleted ', 100, 'loss: ', 2.6158306896686554)
# ('Epoch ', 8, 'conpleted ', 100, 'loss: ', 2.508183479309082)
# ('Epoch ', 9, 'conpleted ', 100, 'loss: ', 2.4155231714248657)
# ('Epoch ', 10, 'conpleted ', 100, 'loss: ', 2.3587916791439056)
# ('Epoch ', 11, 'conpleted ', 100, 'loss: ', 2.3860493302345276)
# ('Epoch ', 12, 'conpleted ', 100, 'loss: ', 2.301751673221588)
# ('Epoch ', 13, 'conpleted ', 100, 'loss: ', 2.2561040222644806)
# ('Epoch ', 14, 'conpleted ', 100, 'loss: ', 2.245759665966034)
# ('Epoch ', 15, 'conpleted ', 100, 'loss: ', 2.236112520098686)
# ('Epoch ', 16, 'conpleted ', 100, 'loss: ', 2.2097592130303383)
# ('Epoch ', 17, 'conpleted ', 100, 'loss: ', 2.1633495688438416)
# ('Epoch ', 18, 'conpleted ', 100, 'loss: ', 2.107569955289364)
# ('Epoch ', 19, 'conpleted ', 100, 'loss: ', 2.121960334479809)
# ('Epoch ', 20, 'conpleted ', 100, 'loss: ', 2.0694607496261597)
# ('Epoch ', 21, 'conpleted ', 100, 'loss: ', 2.0619761496782303)
# ('Epoch ', 22, 'conpleted ', 100, 'loss: ', 2.134148597717285)
# ('Epoch ', 23, 'conpleted ', 100, 'loss: ', 2.0292116925120354)
# ('Epoch ', 24, 'conpleted ', 100, 'loss: ', 2.056675374507904)
# ('Epoch ', 25, 'conpleted ', 100, 'loss: ', 1.967589631676674)
# ('Epoch ', 26, 'conpleted ', 100, 'loss: ', 1.929641429334879)
# ('Epoch ', 27, 'conpleted ', 100, 'loss: ', 1.9317382723093033)
# ('Epoch ', 28, 'conpleted ', 100, 'loss: ', 1.916497103869915)
# ('Epoch ', 29, 'conpleted ', 100, 'loss: ', 1.8817939013242722)
# ('Epoch ', 30, 'conpleted ', 100, 'loss: ', 1.8090306334197521)
# ('Epoch ', 31, 'conpleted ', 100, 'loss: ', 1.768559291958809)
# ('Epoch ', 32, 'conpleted ', 100, 'loss: ', 1.724785652011633)
# ('Epoch ', 33, 'conpleted ', 100, 'loss: ', 1.638540580868721)
# ('Epoch ', 34, 'conpleted ', 100, 'loss: ', 1.6406573913991451)
# ('Epoch ', 35, 'conpleted ', 100, 'loss: ', 1.5229730308055878)
# ('Epoch ', 36, 'conpleted ', 100, 'loss: ', 1.6046706587076187)
# ('Epoch ', 37, 'conpleted ', 100, 'loss: ', 1.414036214351654)
# ('Epoch ', 38, 'conpleted ', 100, 'loss: ', 1.444639539346099)
# ('Epoch ', 39, 'conpleted ', 100, 'loss: ', 1.685834288597107)
# ('Epoch ', 40, 'conpleted ', 100, 'loss: ', 1.3331841081380844)
# ('Epoch ', 75, 'conpleted ', 100, 'loss: ', 0.1722941529005766)
# ('Epoch ', 76, 'conpleted ', 100, 'loss: ', 0.1842325758188963)
# ('Epoch ', 77, 'conpleted ', 100, 'loss: ', 0.15701057761907578)
# ('Epoch ', 78, 'conpleted ', 100, 'loss: ', 0.15435813553631306)
# ('Epoch ', 79, 'conpleted ', 100, 'loss: ', 0.16992178931832314)
# ('Epoch ', 80, 'conpleted ', 100, 'loss: ', 0.14678155537694693)
# ('Epoch ', 81, 'conpleted ', 100, 'loss: ', 0.1390341380611062)
# ('Epoch ', 82, 'conpleted ', 100, 'loss: ', 0.1540808416903019)
# ('Epoch ', 83, 'conpleted ', 100, 'loss: ', 0.1344083482399583)
# ('Epoch ', 84, 'conpleted ', 100, 'loss: ', 0.12987443432211876)
# ('Epoch ', 85, 'conpleted ', 100, 'loss: ', 0.14102386683225632)
# ('Epoch ', 86, 'conpleted ', 100, 'loss: ', 0.12458782456815243)
# ('Epoch ', 87, 'conpleted ', 100, 'loss: ', 0.11986036133021116)
# ('Epoch ', 88, 'conpleted ', 100, 'loss: ', 0.1300485087558627)
# ('Epoch ', 89, 'conpleted ', 100, 'loss: ', 0.1169899944216013)
# ('Epoch ', 90, 'conpleted ', 100, 'loss: ', 0.11167413089424372)
# ('Epoch ', 91, 'conpleted ', 100, 'loss: ', 0.12069391924887896)
# ('Epoch ', 92, 'conpleted ', 100, 'loss: ', 0.10807860549539328)
# ('Epoch ', 93, 'conpleted ', 100, 'loss: ', 0.10339577961713076)
# ('Epoch ', 94, 'conpleted ', 100, 'loss: ', 0.114249924197793)
# ('Epoch ', 95, 'conpleted ', 100, 'loss: ', 0.10298336483538151)
# ('Epoch ', 96, 'conpleted ', 100, 'loss: ', 0.09597799833863974)
# ('Epoch ', 97, 'conpleted ', 100, 'loss: ', 0.10500241490080953)
# ('Epoch ', 98, 'conpleted ', 100, 'loss: ', 0.09737788513302803)
# ('Epoch ', 99, 'conpleted ', 100, 'loss: ', 0.0921507989987731)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-51a5e0e4b4a7> in <module>()
#       2 oy=get_data("y_data.txt")
#       3
# ----> 4 train_neural_network(ox,oy)
#
# <ipython-input-11-66834e2eb337> in train_neural_network(train_x, train_y)
#      21             print('Epoch ',epoch,'conpleted ',hm_epochs,'loss: ',epoch_loss)
#      22
# ---> 23         save_path = saver.save(sess, "mymodel")
#      24
#      25         m=sess.run(prediction,feed_dict={x:train_x})
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/training/saver.pyc in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state)
#    1612               "Parent directory of {} doesn't exist, can't save.".format(
#    1613                   save_path))
# -> 1614         raise exc
#    1615
#    1616     if write_meta_graph:
#
# ValueError: Parent directory of mymodel doesn't exist, can't save.
