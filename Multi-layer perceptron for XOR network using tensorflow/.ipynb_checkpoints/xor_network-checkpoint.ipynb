# %%
import tensorflow as tf
import numpy as np

#define the network
nodes_input=2
nodes_hidden_1=50
nodes_output=2

batch_size=1;

x=tf.placeholder('float',[None,2])
y=tf.placeholder('float')

#Define weights for neural network
hidden_l1={'weights':tf.Variable(tf.random_normal([nodes_input,nodes_hidden_1])),'biases':tf.Variable(tf.random_normal([nodes_hidden_1]))}
    
output_layer={'weights':tf.Variable(tf.random_normal([nodes_hidden_1,nodes_output])),'biases':tf.Variable(tf.random_normal([nodes_output]))}

# %%
def get_data(xh):     #function to read data from file
    datafile=open(xh,"r")
    datalist=[]
    for line in datafile:
        z=line.split(",")
        xg=[float(i) for i in z]
        datalist.append(xg)
    f=np.matrix(datalist)
    return datalist

# %%
def xor_nn(data):
    
    #feed forward throught the network
    l1=tf.add(tf.matmul(data,hidden_l1['weights']),hidden_l1['biases'])
    l1=tf.nn.relu(l1)
    
    output=tf.add(tf.matmul(l1,output_layer['weights']),output_layer['biases'])
    return tf.nn.sigmoid(output)

# %%
def train_neural_network(train_x,train_y):
    prediction=xor_nn(x)
    cost=tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=prediction,labels=y))

    optimizer=tf.train.GradientDescentOptimizer(0.3).minimize(cost)

    hm_epochs=100

    with tf.Session() as sess:
        sess.run(tf.initialize_all_variables())

        for epoch in range(hm_epochs):
            epoch_loss=0
            _,c=sess.run([optimizer,cost],feed_dict={x:train_x,y:train_y})
            epoch_loss+=c
            print('Epoch ',epoch,'conpleted ',hm_epochs,'loss: ',epoch_loss)
            correct=tf.equal(tf.argmax(prediction,1),tf.argmax(y,1))
            accuracy=tf.reduce_mean(tf.cast(correct,'float'))
        
        print(sess.run(prediction,feed_dict={x:train_x}))

# %%
ox=get_data("x_data.txt")
oy=get_data("y_data.txt")

train_neural_network(ox,oy)
# Out:
# ('Epoch ', 0, 'conpleted ', 100, 'loss: ', 0.7839762568473816)
# ('Epoch ', 1, 'conpleted ', 100, 'loss: ', 0.7606842517852783)
# ('Epoch ', 2, 'conpleted ', 100, 'loss: ', 0.7391799688339233)
# ('Epoch ', 3, 'conpleted ', 100, 'loss: ', 0.7123332619667053)
# ('Epoch ', 4, 'conpleted ', 100, 'loss: ', 0.6725919246673584)
# ('Epoch ', 5, 'conpleted ', 100, 'loss: ', 0.6322425603866577)
# ('Epoch ', 6, 'conpleted ', 100, 'loss: ', 0.5941522717475891)
# ('Epoch ', 7, 'conpleted ', 100, 'loss: ', 0.5691128373146057)
# ('Epoch ', 8, 'conpleted ', 100, 'loss: ', 0.5609878897666931)
# ('Epoch ', 9, 'conpleted ', 100, 'loss: ', 0.5567066669464111)
# ('Epoch ', 10, 'conpleted ', 100, 'loss: ', 0.5533292293548584)
# ('Epoch ', 11, 'conpleted ', 100, 'loss: ', 0.5504489541053772)
# ('Epoch ', 12, 'conpleted ', 100, 'loss: ', 0.5479264259338379)
# ('Epoch ', 13, 'conpleted ', 100, 'loss: ', 0.5456705093383789)
# ('Epoch ', 14, 'conpleted ', 100, 'loss: ', 0.5436221361160278)
# ('Epoch ', 15, 'conpleted ', 100, 'loss: ', 0.5417894124984741)
# ('Epoch ', 16, 'conpleted ', 100, 'loss: ', 0.5400892496109009)
# ('Epoch ', 17, 'conpleted ', 100, 'loss: ', 0.5385693311691284)
# ('Epoch ', 18, 'conpleted ', 100, 'loss: ', 0.5371438264846802)
# ('Epoch ', 19, 'conpleted ', 100, 'loss: ', 0.5358584523200989)
# ('Epoch ', 20, 'conpleted ', 100, 'loss: ', 0.534662127494812)
# ('Epoch ', 21, 'conpleted ', 100, 'loss: ', 0.5335549116134644)
# ('Epoch ', 22, 'conpleted ', 100, 'loss: ', 0.5325379371643066)
# ('Epoch ', 23, 'conpleted ', 100, 'loss: ', 0.5315707921981812)
# ('Epoch ', 24, 'conpleted ', 100, 'loss: ', 0.5306859612464905)
# ('Epoch ', 25, 'conpleted ', 100, 'loss: ', 0.5298407077789307)
# ('Epoch ', 26, 'conpleted ', 100, 'loss: ', 0.5290564298629761)
# ('Epoch ', 27, 'conpleted ', 100, 'loss: ', 0.5283209085464478)
# ('Epoch ', 28, 'conpleted ', 100, 'loss: ', 0.5276114344596863)
# ('Epoch ', 29, 'conpleted ', 100, 'loss: ', 0.526960015296936)
# ('Epoch ', 30, 'conpleted ', 100, 'loss: ', 0.5263299942016602)
# ('Epoch ', 31, 'conpleted ', 100, 'loss: ', 0.5257527828216553)
# ('Epoch ', 32, 'conpleted ', 100, 'loss: ', 0.5252014994621277)
# ('Epoch ', 33, 'conpleted ', 100, 'loss: ', 0.5246720314025879)
# ('Epoch ', 34, 'conpleted ', 100, 'loss: ', 0.5241786241531372)
# ('Epoch ', 35, 'conpleted ', 100, 'loss: ', 0.5236996412277222)
# ('Epoch ', 36, 'conpleted ', 100, 'loss: ', 0.5232466459274292)
# ('Epoch ', 37, 'conpleted ', 100, 'loss: ', 0.5228118300437927)
# ('Epoch ', 38, 'conpleted ', 100, 'loss: ', 0.5223934054374695)
# ('Epoch ', 39, 'conpleted ', 100, 'loss: ', 0.521999180316925)
# ('Epoch ', 40, 'conpleted ', 100, 'loss: ', 0.5216148495674133)
# ('Epoch ', 41, 'conpleted ', 100, 'loss: ', 0.5212479829788208)
# ('Epoch ', 42, 'conpleted ', 100, 'loss: ', 0.5208966732025146)
# ('Epoch ', 43, 'conpleted ', 100, 'loss: ', 0.5205561518669128)
# ('Epoch ', 44, 'conpleted ', 100, 'loss: ', 0.5202339887619019)
# ('Epoch ', 45, 'conpleted ', 100, 'loss: ', 0.5199192762374878)
# ('Epoch ', 46, 'conpleted ', 100, 'loss: ', 0.519614040851593)
# ('Epoch ', 47, 'conpleted ', 100, 'loss: ', 0.5193239450454712)
# ('Epoch ', 48, 'conpleted ', 100, 'loss: ', 0.5190349817276001)
# ('Epoch ', 49, 'conpleted ', 100, 'loss: ', 0.5187568664550781)
# ('Epoch ', 50, 'conpleted ', 100, 'loss: ', 0.5184909105300903)
# ('Epoch ', 51, 'conpleted ', 100, 'loss: ', 0.5182301998138428)
# ('Epoch ', 52, 'conpleted ', 100, 'loss: ', 0.5179816484451294)
# ('Epoch ', 53, 'conpleted ', 100, 'loss: ', 0.5177412033081055)
# ('Epoch ', 54, 'conpleted ', 100, 'loss: ', 0.5175050497055054)
# ('Epoch ', 55, 'conpleted ', 100, 'loss: ', 0.517279863357544)
# ('Epoch ', 56, 'conpleted ', 100, 'loss: ', 0.5170590877532959)
# ('Epoch ', 57, 'conpleted ', 100, 'loss: ', 0.5168440937995911)
# ('Epoch ', 58, 'conpleted ', 100, 'loss: ', 0.5166398286819458)
# ('Epoch ', 59, 'conpleted ', 100, 'loss: ', 0.5164377093315125)
# ('Epoch ', 60, 'conpleted ', 100, 'loss: ', 0.5162424445152283)
# ('Epoch ', 61, 'conpleted ', 100, 'loss: ', 0.5160562992095947)
# ('Epoch ', 62, 'conpleted ', 100, 'loss: ', 0.5158705711364746)
# ('Epoch ', 63, 'conpleted ', 100, 'loss: ', 0.5156919956207275)
# ('Epoch ', 64, 'conpleted ', 100, 'loss: ', 0.5155189633369446)
# ('Epoch ', 65, 'conpleted ', 100, 'loss: ', 0.5153481960296631)
# ('Epoch ', 66, 'conpleted ', 100, 'loss: ', 0.5151842832565308)
# ('Epoch ', 67, 'conpleted ', 100, 'loss: ', 0.5150240659713745)
# ('Epoch ', 68, 'conpleted ', 100, 'loss: ', 0.5148668885231018)
# ('Epoch ', 69, 'conpleted ', 100, 'loss: ', 0.5147171020507812)
# ('Epoch ', 70, 'conpleted ', 100, 'loss: ', 0.514568567276001)
# ('Epoch ', 71, 'conpleted ', 100, 'loss: ', 0.5144227743148804)
# ('Epoch ', 72, 'conpleted ', 100, 'loss: ', 0.5142832398414612)
# ('Epoch ', 73, 'conpleted ', 100, 'loss: ', 0.5141451358795166)
# ('Epoch ', 74, 'conpleted ', 100, 'loss: ', 0.514009952545166)
# ('Epoch ', 75, 'conpleted ', 100, 'loss: ', 0.5138802528381348)
# ('Epoch ', 76, 'conpleted ', 100, 'loss: ', 0.5137515068054199)
# ('Epoch ', 77, 'conpleted ', 100, 'loss: ', 0.5136265754699707)
# ('Epoch ', 78, 'conpleted ', 100, 'loss: ', 0.5135064125061035)
# ('Epoch ', 79, 'conpleted ', 100, 'loss: ', 0.5133860111236572)
# ('Epoch ', 80, 'conpleted ', 100, 'loss: ', 0.5132688283920288)
# ('Epoch ', 81, 'conpleted ', 100, 'loss: ', 0.5131560564041138)
# ('Epoch ', 82, 'conpleted ', 100, 'loss: ', 0.5130437612533569)
# ('Epoch ', 83, 'conpleted ', 100, 'loss: ', 0.512934148311615)
# ('Epoch ', 84, 'conpleted ', 100, 'loss: ', 0.5128284096717834)
# ('Epoch ', 85, 'conpleted ', 100, 'loss: ', 0.5127233266830444)
# ('Epoch ', 86, 'conpleted ', 100, 'loss: ', 0.5126215219497681)
# ('Epoch ', 87, 'conpleted ', 100, 'loss: ', 0.5125223398208618)
# ('Epoch ', 88, 'conpleted ', 100, 'loss: ', 0.5124233961105347)
# ('Epoch ', 89, 'conpleted ', 100, 'loss: ', 0.5123269557952881)
# ('Epoch ', 90, 'conpleted ', 100, 'loss: ', 0.5122338533401489)
# ('Epoch ', 91, 'conpleted ', 100, 'loss: ', 0.5121408700942993)
# ('Epoch ', 92, 'conpleted ', 100, 'loss: ', 0.5120501518249512)
# ('Epoch ', 93, 'conpleted ', 100, 'loss: ', 0.511962354183197)
# ('Epoch ', 94, 'conpleted ', 100, 'loss: ', 0.5118753910064697)
# ('Epoch ', 95, 'conpleted ', 100, 'loss: ', 0.5117899775505066)
# ('Epoch ', 96, 'conpleted ', 100, 'loss: ', 0.5117071866989136)
# ('Epoch ', 97, 'conpleted ', 100, 'loss: ', 0.5116244554519653)
# ('Epoch ', 98, 'conpleted ', 100, 'loss: ', 0.5115435719490051)
# ('Epoch ', 99, 'conpleted ', 100, 'loss: ', 0.5114654302597046)
# [[9.8209149e-01 9.9998748e-01]
#  [1.2755866e-02 9.8163790e-01]
#  [1.6153971e-02 9.8484486e-01]
#  [4.7479971e-06 1.3483604e-02]]
